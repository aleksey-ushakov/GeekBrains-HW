# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Урок 1. Задание 4

# %% [markdown]
# Постройте на одном графике две кривые y(x) для функции двух переменной y(k,x)=cos(k∙x), взяв для одной кривой значение k=1, а для другой – любое другое k, не равное

# %%
x = np.linspace(-10,10,501)
plt.plot(x,np.cos(x),label='y = cos(x)')
plt.plot(x,np.cos(0.5*x),label='y = cos(2x)')
plt.legend()

# %% [markdown]
# ### Урок 2. Задание 1

# %% [markdown]
# Даны два вектора в трехмерном пространстве: (20,20,20) и (0,0,-20)
#
# 2)	Напишите код на Python, реализующий расчет длины вектора, заданного его координатами. (в программе)

# %%
a = [1, 2, 3]
len_a = sum([i ** 2 for i in a]) ** 0.5
print('Длинна вектора', a, '-' , len_a)
# Out:
# Длинна вектора [1, 2, 3] - 3.7416573867739413

# %% [markdown]
# ### Урок 2. Задание 3

# %% [markdown]
# Напишите код на Python, реализующий построение графиков:
# 1.	окружности,
# 2.	эллипса,
# 3.	гиперболы.

# %%
x = np.linspace(-10,10,2001)
plt.plot(x, (64 - x**2) ** 0.5, color='red')
plt.plot(x, - (64 - x**2) ** 0.5, color='red')
plt.plot(x, 0.1/ x)
plt.plot(x, - (9 - x**2 / 7) ** 0.5, color='green', linestyle = '--')
plt.plot(x, (9 - x**2 / 7) ** 0.5, color='green', linestyle = '--')
plt.plot(x, (9 - x**2) ** 0.5 * 2.65, color='green', linestyle = '--')
plt.plot(x, -(9 - x**2) ** 0.5 * 2.65, color='green', linestyle = '--')

plt.gca().set_aspect('equal')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in sqrt
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sqrt
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in sqrt
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in sqrt
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in sqrt
#   import sys
# ...

# %% [markdown]
# ### Урок 2. Задание 5

# %% [markdown]
# 1)	Нарисуйте трехмерный график двух параллельных плоскостей

# %%
from mpl_toolkits.mplot3d import Axes3D
from pylab import *
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5, 5, 0.2)
Y = np.arange(-5, 5, 0.2)
X, Y = np.meshgrid(X,Y)
Z = X + Y
ax.plot_wireframe(X,Y,Z)
ax.plot_wireframe(X,Y,Z+10)

# %% [markdown]
# 2)	Нарисуйте трехмерный график двух любых поверхностей второго порядка

# %%
fig = figure()
ax = Axes3D(fig)
ax.plot_wireframe(X,Y, X**2 + Y**2)
ax.plot_wireframe(X,Y, (296 - X ** 2 * 25 - Y ** 2 * 25) ** 0.5 + 50, color='red')
ax.plot_wireframe(X,Y, -(296 - X ** 2 * 25 - Y ** 2*25) ** 0.5   + 50, color='red')
#ax.plot_wireframe(X,Y,Z+10)
#show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in sqrt
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in sqrt

# %% [markdown]
# ### Урок 3. Задание 1

# %% [markdown]
# Нарисуйте график функции:
# y(x) = k∙cos(x – a) + b
# для некоторых (2-3 различных) значений параметров k, a, b

# %%
x = np.linspace(-10,10,501)
plt.plot(x,np.cos(x - 1) * 2 - 2 ,label='Circle = 2 * cos(x - 1) - 2')
plt.plot(x,np.cos(x - 2) + 1,label='Circle = cos(x - 2) + 1')
plt.plot(x,np.cos(x +1 ) * 3 + 2, label='Circle = 3 * cos(x + 1) + 2')
plt.legend()

# %% [markdown]
# ### Урок 3. Задание 3
# 1)	Напишите код, который будет переводить полярные координаты в декартовы.
#
# 2)	Напишите код, который будет рисовать график окружности в полярных координатах.

# %% [markdown]
# ### Урок 3. Задание 4
#
# 1)	Решите систему уравнений:
# y = x2 – 1
# exp(x) + x∙(1 – y) = 1
#
# 2)	Решите неравенство:
# y = x2 – 1
# exp(x) + x∙(1 – y) > 1
